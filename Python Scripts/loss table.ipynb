# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
loss_unet_train=np.array([0.4987,0.1388,0.0542,0.0399,0.0750,0.0773,0.0645,0.0359,0.0347,0.0346,0.0345,0.0345,0.0345,0.0345,0.0345])
loss_unet_test=np.array([0.3817,0.1122,0.0729,0.0699,0.0671,0.1958,0.0903,0.0855,0.0835,0.0822,0.0812,0.0803,0.0797,0.0793,0.0790])
epoch_unet=np.array(range(1,16))

loss_conv_train=np.array([0.0269,0.0276,0.0265,0.0258,0.0277,0.0271,0.0248,0.0250,0.0246,0.0249,0.0239,0.0236,0.0223,
                          0.0225,0.0213,0.0218,0.0215,0.0213,0.0198,0.0201,0.0193,0.0199,0.0204,0.0202,0.0214])
loss_conv_test=np.array([0.3747,0.3706,0.3664,0.3640,0.3625,0.3609,0.3588,0.3558,0.3545,0.3527,0.3516,0.3502,0.3475,
                         0.3460,0.3445,0.3434,0.3446,0.3451,0.3449,0.3430,0.3440,0.3455,0.3505,0.3506,0.3485])
epoch_conv=np.array(range(1,26))

# %%
plt.plot(epoch_unet,loss_unet_train,'-.',epoch_unet, loss_unet_test,color='blue')

plt.plot(epoch_conv,loss_conv_train,'-.',epoch_conv, loss_conv_test,color='orange')
  
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title('Models losses')
plt.legend(["U-net CNN train", "U-net CNN test","ConvLSTM train","ConvLSTM test"])
plt.show()
